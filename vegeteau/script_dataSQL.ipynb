# %%
import random

# création du modèle 
print("""CREATE TABLE interface_graphique (
    date datetime,
    temp_entree decimal(6,2),
    o2_dissous_entree decimal(6,2),
    ph_entree decimal(6,2),
    debit_entree decimal(6,2),
    taux_N_entree decimal(6,2),
    taux_P_entree decimal(6,2),
    temp_air decimal(6,2),
    taux_co2_air decimal(6,2),
    taux_o2_air decimal(6,2),
    humidite_air decimal(6,2),
    flux_air decimal(6,2),
    rayonnement_solaire decimal(6,2),
    temp_sortie decimal(6,2),
    o2_dissous_sortie decimal(6,2),
    ph_sortie decimal(6,2),
    taux_N_sortie decimal(6,2),
    taux_P_sortie decimal(6,2),
    quantite_eau_transpi decimal(6,2),
    temp_transpi decimal(6,2),
    o2_dissous_transpi decimal(6,2),
    ph_transpi decimal(6,2),
    taux_N_transpi decimal(6,2),
    taux_P_transpi decimal(6,2)
    
)""")

#Pour un jour
for i in range(0,3):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(4.7,5.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(3,5):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(5,6):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(6.7,7.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(6,7):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(7.7,8.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(7,8):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(8,10):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(11.7,12.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(10,12):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(14.7,15.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(12,14):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(13.7,14.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(14,17):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(12.7,13.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(17,19):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(9.7,10.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(19,21):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(21,24):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-01 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))



#Pour un jour
for i in range(0,3):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(4.7,5.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(3,5):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(5,6):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(6.7,7.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(6,7):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(7.7,8.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(7,8):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(8,10):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(11.7,12.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(10,12):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(14.7,15.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(12,14):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(13.7,14.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(14,17):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(12.7,13.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(17,19):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(9.7,10.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(19,21):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(21,24):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-02 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))


#Pour un jour
for i in range(0,3):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(4.7,5.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(3,5):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(5,6):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(6.7,7.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(6,7):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(7.7,8.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(7,8):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(8,10):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(11.7,12.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(10,12):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(14.7,15.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(12,14):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(13.7,14.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(14,17):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(12.7,13.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(17,19):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(9.7,10.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(19,21):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(8.7,9.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))

for i in range(21,24):
    print('''
INSERT INTO `interface_graphique`(`date`, `temp_entree`, `o2_dissous_entree`, `ph_entree`, `debit_entree`, `taux_N_entree`,`taux_P_entree`, `temp_air`, `taux_co2_air`, `taux_o2_air`, `humidite_air`, `flux_air`, `rayonnement_solaire`, `temp_sortie`, `o2_dissous_sortie`, `ph_sortie`, `taux_N_sortie`,`taux_P_sortie`,`quantite_eau_transpi`,`temp_transpi`,`o2_dissous_transpi`,`ph_transpi`,`taux_N_transpi`,`taux_P_transpi`) 
VALUES (DATE_ADD('2019-01-03 00:00:00',INTERVAL {counter} HOUR),{te},{to2e},{phe},{de},{tne},{tpe},{ta},{tco2a},{to2a},{ha},{fa},{rs},{ts},{to2s},{ps},{tns},{tps},{qet},{tt},{to2t},{pt},{tnt},{tpt});
'''.format(counter=i,te=random.uniform(5.7,6.3),to2e=random.uniform(7.2,8.5),phe=random.uniform(6,6.8),de=random.uniform(52,55),tne=random.uniform(26.5,32),tpe=random.uniform(0.2,0.8),ta=random.uniform(26,27),tco2a=random.uniform(0.02,0.06),to2a=random.uniform(20.80,21.05),ha=random.uniform(70,90),fa=random.uniform(0,5),rs=random.uniform(0.78,1.1),ts=random.uniform(15,18),to2s=random.uniform(9.8,10.2),ps=random.uniform(6.8,7.2),tns=random.uniform(25,27),tps=random.uniform(0.15,0.28),qet=random.uniform(0,100),tt=random.uniform(15,18),to2t=random.uniform(9.8,10),pt=random.uniform(6.9,7.1),tnt=random.uniform(20,24),tpt=random.uniform(0,0.25)))
# Out:
# CREATE TABLE interface_graphique (
#     date datetime,
#     temp_entree decimal(6,2),
#     o2_dissous_entree decimal(6,2),
#     ph_entree decimal(6,2),
#     debit_entree decimal(6,2),
#     taux_N_entree decimal(6,2),
#     taux_P_entree decimal(6,2),
#     temp_air decimal(6,2),
#     taux_co2_air decimal(6,2),
#     taux_o2_air decimal(6,2),
#     humidite_air decimal(6,2),
#     flux_air decimal(6,2),
#     rayonnement_solaire decimal(6,2),
#     temp_sortie decimal(6,2),
#     o2_dissous_sortie decimal(6,2),
#     ph_sortie decimal(6,2),
#     taux_N_sortie decimal(6,2),
#     taux_P_sortie decimal(6,2),
#     quantite_eau_transpi decimal(6,2),
#     temp_transpi decimal(6,2),
#     o2_dissous_transpi decimal(6,2),
#     ph_transpi decimal(6,2),
#     taux_N_transpi decimal(6,2),
#     taux_P_transpi decimal(6,2),
#
# )
#
# ...
